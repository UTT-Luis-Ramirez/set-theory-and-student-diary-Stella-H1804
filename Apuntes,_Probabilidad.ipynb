# %% [markdown]
# #**PROBABILIDAD**
#
# *Ciencia que estudia los eventos y conceptos abstractos, también estudia la teoría de conjuntos.*

# %% [markdown]
# *EVENTO* : Un suseso que se obtiene a través de otra fuerza.
#
# + Concepto abtracto que es un desencadenador de eventos

# %% [markdown]
# ##**1. Teoria de conjuntos**
#
# ---
# *Utiliza la notación científica y matemática*
#
# ---
# En la teoría de conjuntos se trabaja con colecciones de elementos que comparten características en común
#
# > Las colecciones son una agrupación de cosas o elementos, los elementos pueden ser números, letras...
#
# + Los conjuntos se representan siempre con una letra mayúscula y los elementos se anotan entre llaves.

# %% [markdown]
# ![teoria-de-conjuntos-fi.png](data:image/png;base64,...)

# %% [markdown]
# ###**Universo**
# ---
#
# Es el conjunto que incluye todos los elementos posibles en un contexto dado. Se denota como **𝑈**
#
# Dentro de este tenemos conjunto y subconjuntos, también vistos como población y muestra en la estadística.

# %% [markdown]
# ![poblacion-y-muestra-en-una-investigacion-del-universo-768x427.png](data:image/png;base64,...)

# %% [markdown]
# ###**Conjunto**
# ---
# son los elementos que se encuentran dentro del universo.
#
# ---
# ###**Subconjunto**
# ---
#
# Conjuntos dentro de los conjuntos que pueden o no unirse.

# %% [markdown]
# ![Probable.png](data:image/png;base64,...)

# %% [markdown]
# **Primer tirada** - ataque normal requiere 4 o mas- se tiran 2 dados para saber si es exitoso - dado1: 1 dado2: 3 - fallidos los 2

# %% [markdown]
# **Segunda tirada** - Ataque rapido requiere que sallga 5 o mas- se tiran 2 dados - dado1: 4  dado2: 6 - 1 exitoso y critico - se tiran 3 dados para saber el daño - 4 , 4, 4 = 12 - duplica daño por ser critico = 24

# %% [markdown]
# **Tercer tirada** (doble tirada) - ataque especial no me acuerdo cual (5 o mayor)- se tiran 3 dados 2 veces - 5,5,4 (2 exitosos) y 4,1,3 (3 fallidos) - se tiran dos dados para ver el daño - 6, 2 - 22 (no se pq)

# %% [markdown]
# Cuarta tirada - ataque normal - se tiran 3 dados - 5,2,2 (1 exitoso) - se tira 1 dado (daño) - 6=12 de daño x ser critico

# %% [markdown]
# Quinta tirada - ataque normal (4 o mas)- se tiran 3 dados - 6,4,2 (2 exitosos) - se tiran 2 dados (daño) - 2,1 - el 2=4 por ser critico - con buff de doble de daño = 10 daño total

# %% [markdown]
# Sexta tirada - ataque rapido con congelacion(5 o mas) - 3 dados 6,6,4 (2 exitosos y criticos) - se tiran 2 dados (daño) - 6,8 - por ser criticos el total es de 28

# %% [markdown]
# Septima tirada - atauq normal (y doble tirada (4 o mas) - se tiran 3 dados 6,6,6 (3 exitosos y criticos) - 12,12,12= 36 - segunda tirada 4,6,4 (aqui no se que paso pero salio 15 de daño) - daño total 5

# %% [markdown]
# Octava - ataque rapido sagrado (doble tirada) - (5 o mas) - 3 dados, 6,4,1 (1 critico) - 3 dados 6,5,2 (1 critico de 2 exitosos) - no me acuerdo de los otros datos - pero el daño total es 44
